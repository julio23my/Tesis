# %%
import networkx as nx

# %%
G = nx.Graph()

# %%
objeto = 'Servidor'

# %%
G.add_node(objeto)

# %%
 G.add_nodes_from(['Router0', 'Router1'])

# %%
G.add_edge('Router0', 'Router1')

# %%
G.number_of_nodes()
# Out:
# 3

# %%
G.number_of_edges()
# Out:
# 1

# %%
G.add_edge('Router0', 'Servidor')

# %%
G.number_of_edges()
# Out:
# 2

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
G = nx.petersen_graph()

# %%
plt.subplot(121)
# Out:
# <AxesSubplot:>

# %%
nx.draw(G, with_labels=True, font_weight='bold')
